# %%
import pandas as pd

read_file = pd.read_csv (r'Resources/South Korea Vaccinations.txt')
read_file.to_csv (r'Resources/South Korea Vaccinations.csv', index=None)
read_file.head(70)
# Out:
#        location        date                              vaccine  \
# 0   South Korea  2021-02-26                   Oxford/AstraZeneca
# 1   South Korea  2021-02-27  Oxford/AstraZeneca, Pfizer/BioNTech
# 2   South Korea  2021-02-28  Oxford/AstraZeneca, Pfizer/BioNTech
# 3   South Korea  2021-03-01  Oxford/AstraZeneca, Pfizer/BioNTech
# 4   South Korea  2021-03-02  Oxford/AstraZeneca, Pfizer/BioNTech
# ..          ...         ...                                  ...
# 65  South Korea  2021-05-02  Oxford/AstraZeneca, Pfizer/BioNTech
# 66  South Korea  2021-05-03  Oxford/AstraZeneca, Pfizer/BioNTech
# 67  South Korea  2021-05-04  Oxford/AstraZeneca, Pfizer/BioNTech
# 68  South Korea  2021-05-05  Oxford/AstraZeneca, Pfizer/BioNTech
# 69  South Korea  2021-05-06  Oxford/AstraZeneca, Pfizer/BioNTech
#
#                  source_url  total_vaccinations  people_vaccinated  \
# 0   https://ncv.kdca.go.kr/               24540              22694
# ...

# %%
clean_df = read_file[read_file['total_vaccinations'] > 0].reset_index( drop = True)
clean_df = clean_df.drop(columns=['source_url', 'total_boosters'])
clean_df
# Out:
#         location        date  \
# 0    South Korea  2021-02-26
# 1    South Korea  2021-02-27
# 2    South Korea  2021-02-28
# 3    South Korea  2021-03-01
# 4    South Korea  2021-03-02
# ..           ...         ...
# 198  South Korea  2021-09-12
# 199  South Korea  2021-09-13
# 200  South Korea  2021-09-14
# 201  South Korea  2021-09-15
# 202  South Korea  2021-09-16
#
#                                                vaccine  total_vaccinations  \
# 0                                   Oxford/AstraZeneca               24540
# 1                  Oxford/AstraZeneca, Pfizer/BioNTech               25966
# 2                  Oxford/AstraZeneca, Pfizer/BioNTech               26830
# 3                  Oxford/AstraZeneca, Pfizer/BioNTech               28364
# 4                  Oxford/AstraZeneca, Pfizer/BioNTech               94794
# ..                                                 ...                 ...
# 198  Oxford/AstraZeneca, Pfizer/BioNTech, Johnson&J...            51918096
# ...
