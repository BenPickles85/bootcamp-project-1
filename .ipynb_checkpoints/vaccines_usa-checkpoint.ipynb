# %%
import pandas as pd

read_file = pd.read_csv (r'Resources/USA Vaccinations.txt')
read_file.to_csv (r'Resources/USA Vaccinations.csv', index=None)
read_file.head(20)
# Out:
#          location  total_vaccinations        date                   vaccine  \
# 0   United States              556208  2020-12-20           Pfizer/BioNTech
# 1   United States              614117  2020-12-21           Pfizer/BioNTech
# 2   United States             1008025  2020-12-23  Moderna, Pfizer/BioNTech
# 3   United States             1944585  2020-12-26  Moderna, Pfizer/BioNTech
# 4   United States             2127143  2020-12-28  Moderna, Pfizer/BioNTech
# 5   United States             2794588  2020-12-30  Moderna, Pfizer/BioNTech
# 6   United States             4225756  2021-01-02  Moderna, Pfizer/BioNTech
# 7   United States             4563260  2021-01-04  Moderna, Pfizer/BioNTech
# 8   United States             4836469  2021-01-05  Moderna, Pfizer/BioNTech
# 9   United States             5306797  2021-01-06  Moderna, Pfizer/BioNTech
# 10  United States             5919418  2021-01-07  Moderna, Pfizer/BioNTech
# 11  United States             6688231  2021-01-08  Moderna, Pfizer/BioNTech
# 12  United States             8987322  2021-01-11  Moderna, Pfizer/BioNTech
# 13  United States             9327138  2021-01-12  Moderna, Pfizer/BioNTech
# 14  United States            10278462  2021-01-13  Moderna, Pfizer/BioNTech
# 15  United States            11148991  2021-01-14  Moderna, Pfizer/BioNTech
# 16  United States            12279180  2021-01-15  Moderna, Pfizer/BioNTech
# 17  United States            15707588  2021-01-19  Moderna, Pfizer/BioNTech
# 18  United States            16525281  2021-01-20  Moderna, Pfizer/BioNTech
# 19  United States            17546374  2021-01-21  Moderna, Pfizer/BioNTech
#
#                                            source_url  people_vaccinated  \
# 0   https://www.cdc.gov/coronavirus/2019-ncov/vacc...           556208.0
# 1   https://covid.cdc.gov/covid-data-tracker/#vacc...           614117.0
# 2   https://covid.cdc.gov/covid-data-tracker/#vacc...          1008025.0
# 3   https://covid.cdc.gov/covid-data-tracker/#vacc...          1944585.0
# 4   https://covid.cdc.gov/covid-data-tracker/#vacc...          2127143.0
# 5   https://covid.cdc.gov/covid-data-tracker/#vacc...          2794588.0
# 6   https://covid.cdc.gov/covid-data-tracker/#vacc...          4225756.0
# 7   https://covid.cdc.gov/covid-data-tracker/#vacc...          4563260.0
# 8   https://covid.cdc.gov/covid-data-tracker/#vacc...          4836469.0
# 9   https://covid.cdc.gov/covid-data-tracker/#vacc...          5306797.0
# 10  https://covid.cdc.gov/covid-data-tracker/#vacc...          5919418.0
# 11  https://covid.cdc.gov/covid-data-tracker/#vacc...          6688231.0
# 12  https://covid.cdc.gov/covid-data-tracker/#vacc...          8987322.0
# 13  https://covid.cdc.gov/covid-data-tracker/#vacc...          9327138.0
# 14  https://covid.cdc.gov/covid-data-tracker/#vacc...                NaN
# 15  https://covid.cdc.gov/covid-data-tracker/#vacc...          9690757.0
# 16  https://covid.cdc.gov/covid-data-tracker/#vacc...         10595866.0
# 17  https://covid.cdc.gov/covid-data-tracker/#vacc...         13595803.0
# 18  https://covid.cdc.gov/covid-data-tracker/#vacc...         14270441.0
# 19  https://covid.cdc.gov/covid-data-tracker/#vacc...         15053257.0
#
#     people_fully_vaccinated  total_boosters
# 0                       NaN             NaN
# 1                       NaN             NaN
# 2                       NaN             NaN
# 3                       NaN             NaN
# 4                       NaN             NaN
# 5                       NaN             NaN
# 6                       NaN             NaN
# 7                       NaN             NaN
# 8                       NaN             NaN
# 9                       NaN             NaN
# 10                      NaN             NaN
# 11                      NaN             NaN
# 12                      NaN             NaN
# 13                      NaN             NaN
# 14                      NaN             NaN
# 15                1342086.0             NaN
# 16                1610524.0             NaN
# 17                2023124.0             NaN
# 18                2161419.0             NaN
# 19                2394961.0             NaN

# %%
clean_df = read_file[read_file['total_vaccinations'] > 0].reset_index( drop = True)
clean_df = clean_df.drop(columns=['source_url', 'total_boosters'])
clean_df
# Out:
#           location  total_vaccinations        date  \
# 0    United States              556208  2020-12-20
# 1    United States              614117  2020-12-21
# 2    United States             1008025  2020-12-23
# 3    United States             1944585  2020-12-26
# 4    United States             2127143  2020-12-28
# ..             ...                 ...         ...
# 249  United States           380831725  2021-09-13
# 250  United States           381453265  2021-09-14
# 251  United States           382294795  2021-09-15
# 252  United States           383038403  2021-09-16
# 253  United States           383994877  2021-09-17
#
#                                        vaccine  people_vaccinated  \
# 0                              Pfizer/BioNTech           556208.0
# 1                              Pfizer/BioNTech           614117.0
# 2                     Moderna, Pfizer/BioNTech          1008025.0
# 3                     Moderna, Pfizer/BioNTech          1944585.0
# 4                     Moderna, Pfizer/BioNTech          2127143.0
# ..                                         ...                ...
# 249  Johnson&Johnson, Moderna, Pfizer/BioNTech        209701005.0
# 250  Johnson&Johnson, Moderna, Pfizer/BioNTech        209982936.0
# 251  Johnson&Johnson, Moderna, Pfizer/BioNTech        210361099.0
# 252  Johnson&Johnson, Moderna, Pfizer/BioNTech        210700361.0
# 253  Johnson&Johnson, Moderna, Pfizer/BioNTech        211097597.0
#
#      people_fully_vaccinated
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 249              178982950.0
# 250              179289983.0
# 251              179695287.0
# 252              180086143.0
# 253              180572171.0
#
# [254 rows x 6 columns]
